# %%
import pandas as pd
import re

# %% [markdown]
# NLP First Setp: Convert text data into numeric data

# %%
# Load DataFrame into variable df
df = pd.read_csv('ExtractedTweets.csv')
df.head()
# Out:
#       Party         Handle                                              Tweet
# 0  Democrat  RepDarrenSoto  Today, Senate Dems vote to #SaveTheInternet. P...
# 1  Democrat  RepDarrenSoto  RT @WinterHavenSun: Winter Haven resident / Al...
# 2  Democrat  RepDarrenSoto  RT @NBCLatino: .@RepDarrenSoto noted that Hurr...
# 3  Democrat  RepDarrenSoto  RT @NALCABPolicy: Meeting with @RepDarrenSoto ...
# 4  Democrat  RepDarrenSoto  RT @Vegalteno: Hurricane season starts on June...

# %%
#Check for null values in the dataset
df.isna().sum()
# Out:
# Party     0
# Handle    0
# Tweet     0
# dtype: int64

# %%
# Check the amount of tweets
df.shape[0]
# Out:
# 86460

# %% [markdown]
# ### Data Cleaning

# %%
# Check of unique values
for col in df.columns:
    selected =  df[col]
    n_unique = selected.unique().shape[0]
    print("The column {:40s} has {:6d} unique values".format(col,n_unique))
# Out:
# The column Party                                    has      2 unique values
# The column Handle                                   has    433 unique values
# The column Tweet                                    has  84502 unique values

# %% [markdown]
# We can see there are more tweets 86,460 than unique tweets 84,502. These duplicate values might be retweets, it is something we should look at.
#
# There is a difference of 1,958 tweets.

# %% [markdown]
# Now we will check for duplicate values

# %%
df[df['Tweet'].duplicated() == True]
# Out:
#             Party           Handle  \
# 675      Democrat     RepEspaillat
# 702      Democrat     RepEspaillat
# 1100     Democrat      RepBarragan
# 1438     Democrat      RepRoKhanna
# 1451     Democrat      RepRoKhanna
# ...           ...              ...
# 86027  Republican  WaysandMeansGOP
# 86035  Republican  WaysandMeansGOP
# 86047  Republican  WaysandMeansGOP
# 86057  Republican  WaysandMeansGOP
# 86061  Republican        GOPpolicy
#
#                                                    Tweet
# 675    RT @OfficialCBC: Join us on Tuesday, May 8, 20...
# 702    RT @DemsEspanol: El senador @marcorubio lo ha ...
# 1100   RT @NRDems: BREAKING: The Trump admin is movin...
# 1438   RT @Nextgov: Bill from @RepRoKhanna and @RepRa...
# 1451   RT @Nextgov: Bill from @RepRoKhanna and @RepRa...
# ...                                                  ...
# 86027  RT @NFIB: Today is the first #TaxDay in years ...
# 86035  RT @SteveScalise: The bad news → today is Tax ...
# 86047  RT @RepKevinBrady: Championed by both Republic...
# 86057  RT @RepKevinBrady: Tomorrow is the LAST time y...
# 86061  RT @HouseGOP: The #TaxCutsandJobsAct brings an...
#
# [1958 rows x 3 columns]

# %% [markdown]
# There are 1,958 duplicate values, which explains the difference obtained above between total tweets and unique tweets.
#
# We are going to show the Tweets that are duplicate and delete them.

# %%
# Create a variable with all of the duplicate tweets.
duplicate_tweets = df[df['Tweet'].duplicated() == True]
duplicate_tweets
# Out:
#             Party           Handle  \
# 675      Democrat     RepEspaillat
# 702      Democrat     RepEspaillat
# 1100     Democrat      RepBarragan
# 1438     Democrat      RepRoKhanna
# 1451     Democrat      RepRoKhanna
# ...           ...              ...
# 86027  Republican  WaysandMeansGOP
# 86035  Republican  WaysandMeansGOP
# 86047  Republican  WaysandMeansGOP
# 86057  Republican  WaysandMeansGOP
# 86061  Republican        GOPpolicy
#
#                                                    Tweet
# 675    RT @OfficialCBC: Join us on Tuesday, May 8, 20...
# 702    RT @DemsEspanol: El senador @marcorubio lo ha ...
# 1100   RT @NRDems: BREAKING: The Trump admin is movin...
# 1438   RT @Nextgov: Bill from @RepRoKhanna and @RepRa...
# 1451   RT @Nextgov: Bill from @RepRoKhanna and @RepRa...
# ...                                                  ...
# 86027  RT @NFIB: Today is the first #TaxDay in years ...
# 86035  RT @SteveScalise: The bad news → today is Tax ...
# 86047  RT @RepKevinBrady: Championed by both Republic...
# 86057  RT @RepKevinBrady: Tomorrow is the LAST time y...
# 86061  RT @HouseGOP: The #TaxCutsandJobsAct brings an...
#
# [1958 rows x 3 columns]

# %%
# Delete de duplicate values
# Make sure we are deleting duplicate tweets but from THE SAME account.
# Duplicate Tweets from different accounts can be considered as separate tweets

# First, show rows where both Handle and Tweets are duplicated.
# The Keep = False will allow us the keep the duplicated and visualize the results
duplicated_df = df[df.duplicated(subset=['Handle','Tweet'], keep = False)]
duplicated_df
# Out:
#             Party          Handle  \
# 1412     Democrat     RepRoKhanna
# 1438     Democrat     RepRoKhanna
# 1451     Democrat     RepRoKhanna
# 3664     Democrat   RepValDemings
# 3683     Democrat   RepValDemings
# ...           ...             ...
# 83346  Republican   cathymcmorris
# 84409  Republican    virginiafoxx
# 84418  Republican    virginiafoxx
# 84744  Republican  LamarSmithTX21
# 84747  Republican  LamarSmithTX21
#
#                                                    Tweet
# 1412   RT @Nextgov: Bill from @RepRoKhanna and @RepRa...
# 1438   RT @Nextgov: Bill from @RepRoKhanna and @RepRa...
# 1451   RT @Nextgov: Bill from @RepRoKhanna and @RepRa...
# 3664                       Good morning Central Florida!
# 3683                       Good morning Central Florida!
# ...                                                  ...
# 83346  Be confident &amp; tell your story. https://t....
# 84409  Save the Date - Veterans Information Session o...
# 84418  Save the Date - Veterans Information Session o...
# 84744  RT @Austin_Police: APD is asking the public to...
# 84747  RT @Austin_Police: APD is asking the public to...
#
# [101 rows x 3 columns]

# %%
#Second, we will delete the duplicates and only keep the first ocurrance
df_cleaned = df.drop_duplicates(subset=['Handle', 'Tweet'], keep='first')
df_cleaned.shape
# Out:
# (86403, 3)

# %% [markdown]
# From the original 86,460 tweets, we have deleted 57 duplicated tweets from the same Handle.
#
# For sanity check, we will check that all of the duplicate Tweets that we left on the dataset, do have a different Handle.

# %%
#Now we will check the amount of duplicated that have a differente 'Handle'

# Identify and display rows where 'Tweets' are duplicated but 'Handle' values are different
duplicates_with_different_handle = df[df.duplicated(subset=['Tweet'], keep=False) & ~df.duplicated(subset=['Tweet', 'Handle'], keep=False)]

# Display the resulting DataFrame
duplicates_with_different_handle
# Out:
#             Party           Handle  \
# 8        Democrat    RepDarrenSoto
# 63       Democrat    RepDarrenSoto
# 82       Democrat    RepDarrenSoto
# 83       Democrat    RepDarrenSoto
# 114      Democrat    RepDarrenSoto
# ...           ...              ...
# 86027  Republican  WaysandMeansGOP
# 86035  Republican  WaysandMeansGOP
# 86047  Republican  WaysandMeansGOP
# 86057  Republican  WaysandMeansGOP
# 86061  Republican        GOPpolicy
#
#                                                    Tweet
# 8      RT @HispanicCaucus: Trump's anti-immigrant pol...
# 63     RT @DemsEspanol: El senador @marcorubio lo ha ...
# 82     RT @HispanicCaucus: Our Members are demanding ...
# 83     RT @RepAnthonyBrown: When I served in Iraq, I ...
# 114    RT @CaucusOnClimate: 11 lost lives. 5 million ...
# ...                                                  ...
# 86027  RT @NFIB: Today is the first #TaxDay in years ...
# 86035  RT @SteveScalise: The bad news → today is Tax ...
# 86047  RT @RepKevinBrady: Championed by both Republic...
# 86057  RT @RepKevinBrady: Tomorrow is the LAST time y...
# 86061  RT @HouseGOP: The #TaxCutsandJobsAct brings an...
#
# [2908 rows x 3 columns]

# %% [markdown]
# There are 2908 duplicate tweets but with different Handle. We want to count the amount of unique handle per duplicate Tweet. The count of these unique handle per duplicate tweet should be 2908 so we can be sure that our dataframe has only duplicate values with unique Handle.

# %%
# Initialize a variable to accumulate the unique handles count
total_unique_handles_count = 0

# Iterate over duplicates and count unique handles
for tweet, group in duplicates_with_different_handle.groupby('Tweet'):
    
    # Obtain all of the unique Handles in the subset group, for each unique Tweet
    unique_handles_count = group['Handle'].nunique()
    
    # Add to the total count, the amount of unique handles per unique Tweet
    total_unique_handles_count += unique_handles_count

# Print the total unique handles count for all tweets
print(f"Total Unique Handles Count for All Tweets: {total_unique_handles_count}")
# Out:
# Total Unique Handles Count for All Tweets: 2908

# %% [markdown]
# Since the total unique handles for the unique Tweets in the duplicates_with_different_handle dataframe is equal to the total of Tweets in that same data frame, we can be sure our dataset is cleaned as desired.

# %% [markdown]
# ### Check for Retweets
# Binary column 'Retweets' will be created with the value of 1 of the Tweet is a retweet.

# %%
#Take a look at the amount of retweets in our data set
df_cleaned[df_cleaned['Tweet'].str.contains('RT')].shape[0]
# Out:
# 19194

# %%
# Percantage of retweets from the whole data set

pct_of_rt = df_cleaned[df_cleaned['Tweet'].str.contains('RT')].shape[0]/df.shape[0]*100
print(f" The percentage of retweets in the dataset is {pct_of_rt}%")
# Out:
#  The percentage of retweets in the dataset is 22.199861207494795%

# %% [markdown]
# Now we know that roughly 22.20% of the tweets in the dataset are retweets. That is a big amount.
#
# We will create a new binary column in the dataset with value of 1 if its a retweet and 0 if it's not.

# %%
# Create new blank columns to determine if tweet is retweeted or not
df_cleaned['Retweet'] = None

#Check results
df_cleaned['Retweet']
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 86455    None
# 86456    None
# 86457    None
# 86458    None
# 86459    None
# Name: Retweet, Length: 86403, dtype: object

# %%
# Fill columns with binary values based on if tweet is retweet or not

df_cleaned['Retweet'] = df_cleaned['Tweet'].apply(lambda x: 1 if 'RT' in x else 0)

#Check to see if the amount of rows where there is a retweet matches with 19,194 the amount of RT previously calcualted
df_cleaned[df_cleaned['Retweet']==1].shape
# Out:
# (19194, 4)

# %%
# Check results and new table
df_cleaned.head(50)
# Out:
#        Party         Handle  \
# 0   Democrat  RepDarrenSoto
# 1   Democrat  RepDarrenSoto
# 2   Democrat  RepDarrenSoto
# 3   Democrat  RepDarrenSoto
# 4   Democrat  RepDarrenSoto
# 5   Democrat  RepDarrenSoto
# 6   Democrat  RepDarrenSoto
# 7   Democrat  RepDarrenSoto
# 8   Democrat  RepDarrenSoto
# 9   Democrat  RepDarrenSoto
# 10  Democrat  RepDarrenSoto
# 11  Democrat  RepDarrenSoto
# 12  Democrat  RepDarrenSoto
# 13  Democrat  RepDarrenSoto
# 14  Democrat  RepDarrenSoto
# 15  Democrat  RepDarrenSoto
# 16  Democrat  RepDarrenSoto
# 17  Democrat  RepDarrenSoto
# 18  Democrat  RepDarrenSoto
# 19  Democrat  RepDarrenSoto
# 20  Democrat  RepDarrenSoto
# 21  Democrat  RepDarrenSoto
# 22  Democrat  RepDarrenSoto
# 23  Democrat  RepDarrenSoto
# 24  Democrat  RepDarrenSoto
# 25  Democrat  RepDarrenSoto
# 26  Democrat  RepDarrenSoto
# 27  Democrat  RepDarrenSoto
# 28  Democrat  RepDarrenSoto
# 29  Democrat  RepDarrenSoto
# 30  Democrat  RepDarrenSoto
# 31  Democrat  RepDarrenSoto
# 32  Democrat  RepDarrenSoto
# 33  Democrat  RepDarrenSoto
# 34  Democrat  RepDarrenSoto
# 35  Democrat  RepDarrenSoto
# 36  Democrat  RepDarrenSoto
# 37  Democrat  RepDarrenSoto
# 38  Democrat  RepDarrenSoto
# 39  Democrat  RepDarrenSoto
# 40  Democrat  RepDarrenSoto
# 41  Democrat  RepDarrenSoto
# 42  Democrat  RepDarrenSoto
# 43  Democrat  RepDarrenSoto
# 44  Democrat  RepDarrenSoto
# 45  Democrat  RepDarrenSoto
# 46  Democrat  RepDarrenSoto
# 47  Democrat  RepDarrenSoto
# 48  Democrat  RepDarrenSoto
# 49  Democrat  RepDarrenSoto
#
#                                                 Tweet  Retweet
# 0   Today, Senate Dems vote to #SaveTheInternet. P...        0
# 1   RT @WinterHavenSun: Winter Haven resident / Al...        1
# 2   RT @NBCLatino: .@RepDarrenSoto noted that Hurr...        1
# 3   RT @NALCABPolicy: Meeting with @RepDarrenSoto ...        1
# 4   RT @Vegalteno: Hurricane season starts on June...        1
# 5   RT @EmgageActionFL: Thank you to all who came ...        1
# 6   Hurricane Maria left approx $90 billion in dam...        0
# 7   RT @Tharryry: I am delighted that @RepDarrenSo...        1
# 8   RT @HispanicCaucus: Trump's anti-immigrant pol...        1
# 9   RT @RepStephMurphy: Great joining @WeAreUnidos...        1
# 10  RT @AllSaints_FL: Zhihan (John)'s art received...        1
# 11  .@realDonaldTrump official policy to separate ...        0
# 12  Thank you to my mom Jean and all the mothers a...        0
# 13  We paid our respects at Nat’l Law Enforcement ...        0
# 14  RT @WinterHavenSun: Congratulations to  @AHSbl...        1
# 15  Meet 12 incredible young leaders appointed to ...        0
# 16  RT @wildlifeaction: With 1/3 of US wildlife in...        1
# 17  RT @CHeathWFTV: Keeping guns out of the wrong ...        1
# 18  RT @GermieNYC: TY, @RepDarrenSoto for calling ...        1
# 19  Behind every successful student, there's a pro...        0
# 20  RT @HeardontheHill: .@RepDarrenSoto recalled p...        1
# 21  RT @NathanHale7476: Got to meet @RepDarrenSoto...        1
# 22  RT @WinterHavenSun: Lead story in the Polk New...        1
# 23  #FACT: 24 percent of Americans said they didn’...        0
# 24  Americans deserve #ABetterDeal on the cost of ...        0
# 25  Thank u @BillNye for being a voice for #Scienc...        0
# 26  RT @RepRubenGallego: Public comment is a respo...        1
# 27  Sat down with @rollcall to discuss fellowship,...        0
# 28  RT @rvivian370: At the Pulse Memorial this mor...        1
# 29  Joined colleagues in opposition to Trump admin...        0
# 30  RT @WFTV: .@RepDarrenSoto calls for regulatory...        1
# 31  Thank you to millions of bright, hardworking t...        0
# 32  RT @WeAreUnidosUS: Thank you @RepDarrenSoto fo...        1
# 33  RT @NAPABA: @RepDarrenSoto — the first Puerto ...        1
# 34  RT @romancerookie: @RepDarrenSoto @SenBillNels...        1
# 35  RT @WaelAlzayat: Thank you @RepDarrenSoto for ...        1
# 36  RT @EmgageActionFL: @RepDarrenSoto addressing ...        1
# 37  RT @news6wkmg: .@RepDarrenSoto talks District ...        1
# 38  Trump continues anti-immigrant, anti-Hispanic ...        0
# 39  RT @YourBarrioFL: Thank you @Emerge_USA for ho...        1
# 40  RT @ricardorossello: También me acompañó en la...        1
# 41  RT @SenBillNelson: Got a firsthand look at the...        1
# 42  RT @garywhite13: Signed by @RepDennisRoss &amp...        1
# 43  It’s with heavy heart that we mourn loss of Ma...        0
# 44  RT @garywhite13: @SenBillNelson, @RepDarrenSot...        1
# 45  RT @SenBillNelson: Had a good discussion tonig...        1
# 46  RT @YourBarrioFL: At the #vamos4pr press confe...        1
# 47  RT @MikeWFerguson: I'm here in Haines City for...        1
# 48  RT @tbhjr: @repdarrensoto I just wrote asking ...        1
# 49  RT @DemsEspanol: El congresista @RepDarrenSoto...        1

# %% [markdown]
# Now we will extract all of the hashtags in the database

# %% [markdown]
# ### Create a new column with all of the hashtags for each tweet

# %%
# Create a new column with the hashtags for each tweet
df_cleaned['Hashtags'] = None

#Iterate over each row in df['Tweets']
for index, row in df_cleaned.iterrows():
    # Use regex findall to search for all hashtags in each row
    hashtags = re.findall(r'#(\w+)', row['Tweet'])
    if hashtags:
        # Add the hashtags, if any, in the columns 'Hashtags' for each row
        df_cleaned.at[index, 'Hashtags'] = hashtags

# %%
df_cleaned['Hashtags']
# Out:
# 0        [SaveTheInternet, NetNeutrality]
# 1                                    None
# 2                                    None
# 3                      [NALCABPolicy2018]
# 4                                    None
#                        ...
# 86455                                None
# 86456                                None
# 86457                                None
# 86458                  [CobbBackToSchool]
# 86459                              [Zika]
# Name: Hashtags, Length: 86403, dtype: object

# %%
# Use regular expression to extract hashtags into a list
hashtag_list = df_cleaned['Tweet'].str.extractall(r'#(\w+)').reset_index()[0]
hashtag_list
# Out:
# 0         SaveTheInternet
# 1           NetNeutrality
# 2        NALCABPolicy2018
# 3           NetNeutrality
# 4                 Orlando
#                ...
# 36621     OpeningCeremony
# 36622             TeamUSA
# 36623                Zika
# 36624    CobbBackToSchool
# 36625                Zika
# Name: 0, Length: 36626, dtype: object

# %%
# Check Results
df_cleaned.head(10)
# Out:
#       Party         Handle                                              Tweet  \
# 0  Democrat  RepDarrenSoto  Today, Senate Dems vote to #SaveTheInternet. P...
# 1  Democrat  RepDarrenSoto  RT @WinterHavenSun: Winter Haven resident / Al...
# 2  Democrat  RepDarrenSoto  RT @NBCLatino: .@RepDarrenSoto noted that Hurr...
# 3  Democrat  RepDarrenSoto  RT @NALCABPolicy: Meeting with @RepDarrenSoto ...
# 4  Democrat  RepDarrenSoto  RT @Vegalteno: Hurricane season starts on June...
# 5  Democrat  RepDarrenSoto  RT @EmgageActionFL: Thank you to all who came ...
# 6  Democrat  RepDarrenSoto  Hurricane Maria left approx $90 billion in dam...
# 7  Democrat  RepDarrenSoto  RT @Tharryry: I am delighted that @RepDarrenSo...
# 8  Democrat  RepDarrenSoto  RT @HispanicCaucus: Trump's anti-immigrant pol...
# 9  Democrat  RepDarrenSoto  RT @RepStephMurphy: Great joining @WeAreUnidos...
#
#    Retweet                          Hashtags
# 0        0  [SaveTheInternet, NetNeutrality]
# 1        1                              None
# 2        1                              None
# 3        1                [NALCABPolicy2018]
# 4        1                              None
# 5        1                              None
# 6        0                              None
# 7        1                   [NetNeutrality]
# 8        1                              None
# 9        1                         [Orlando]

# %% [markdown]
# ### Checkpoint
# Until now, we have done the following with out dataset:
# 1. Check for null values.
# 2. Remove duplicate Tweets where the Handle was also duplicate.
# 3. Create a RT binary column to mark all tweets which are RTs: 1 if it is a retweet, otherwise 0.
# 4. Create a Hashtags column which shows all of the hashtags, if any, for every tweet.
# 5. Create a list called **hashtag_list** with all of the hashtags that appear in the DataSet
#
#
# So now, are cleaned DataFrame has been saved as the variable **df_cleaned**.
#
# - The original **df** DataFrame is outdated from this point on.
# - The DataFrame **duplicate_tweets** shows ALL of the duplicate Tweets.
# - The DataFrame **duplicates_with_different_handle** shows ALL of the duplicate Tweets which are coming from different handles.

# %%
#Save the new DataFrame

df_cleaned.to_csv('PoliticalTweets.csv')
